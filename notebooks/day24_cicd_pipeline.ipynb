# %%
print("""
Day 24 - GitHub Actions CI/CD Pipeline

Objective:
- Create GitHub Actions Workflow
- Automate Build Process
- Validate Python Environment
- Prepare Deployment Pipeline
""")
# Out:
# Day 24 - GitHub Actions CI/CD Pipeline
#
# Objective:
# - Create GitHub Actions Workflow
# - Automate Build Process
# - Validate Python Environment
# - Prepare Deployment Pipeline

# %%
import os

os.makedirs("../.github/workflows", exist_ok=True)

print("GitHub workflow folder created")
# Out:
# GitHub workflow folder created

# %%
workflow_yaml = """
name: RetailPulse CI Pipeline

on:
  push:
    branches:
      - main

  pull_request:
    branches:
      - main

jobs:
  build:

    runs-on: ubuntu-latest

    steps:

    - name: Checkout Repository
      uses: actions/checkout@v4

    - name: Setup Python
      uses: actions/setup-python@v5
      with:
        python-version: "3.12"

    - name: Install Dependencies
      run: |
        pip install pandas
        pip install streamlit
        pip install plotly

    - name: Verify Installation
      run: |
        python --version
        pip list
"""

with open("../.github/workflows/retailpulse-ci.yml", "w") as f:
    f.write(workflow_yaml)

print("retailpulse-ci.yml created")
# Out:
# retailpulse-ci.yml created

# %%
with open("../.github/workflows/retailpulse-ci.yml", "r") as f:
    print(f.read())
# Out:
# name: RetailPulse CI Pipeline
#
# on:
#   push:
#     branches:
#       - main
#
#   pull_request:
#     branches:
#       - main
#
# jobs:
#   build:
#
#     runs-on: ubuntu-latest
#
#     steps:
#
#     - name: Checkout Repository
#       uses: actions/checkout@v4
#
#     - name: Setup Python
#       uses: actions/setup-python@v5
#       with:
#         python-version: "3.12"
#
#     - name: Install Dependencies
#       run: |
#         pip install pandas
#         pip install streamlit
#         pip install plotly
#
#     - name: Verify Installation
#       run: |
#         python --version
#         pip list

# %%
import os

workflow_exists = os.path.exists(
    "../.github/workflows/retailpulse-ci.yml"
)

print("Workflow Exists:", workflow_exists)
# Out:
# Workflow Exists: True

# %%
with open("../.github/workflows/retailpulse-ci.yml","r") as f:
    lines = f.readlines()

print("Total Lines:", len(lines))
# Out:
# Total Lines: 37

# %%
print("""
Day 24 Completed Successfully

Features Implemented:
- GitHub Actions Workflow
- Automated Build Pipeline
- Python Environment Setup
- Dependency Installation
- CI Validation Process

Artifacts Created:
- .github/workflows/retailpulse-ci.yml

Status: COMPLETE
""")
# Out:
# Day 24 Completed Successfully
#
# Features Implemented:
# - GitHub Actions Workflow
# - Automated Build Pipeline
# - Python Environment Setup
# - Dependency Installation
# - CI Validation Process
#
# Artifacts Created:
# - .github/workflows/retailpulse-ci.yml
#
# Status: COMPLETE
