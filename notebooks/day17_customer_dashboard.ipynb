# %%
print("Day 17 - Customer Analytics Dashboard")
# Out:
# Day 17 - Customer Analytics Dashboard

# %%
import pandas as pd

segment_df = pd.read_csv(
    "../data/processed/customer_segments.csv"
)

churn_df = pd.read_csv(
    "../data/processed/churn_predictions.csv"
)

segment_df.head()
# Out:
#    Customer ID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0      12346.0      326         12  77556.46        2        5        5
# 1      12347.0        2          8   5633.32        5        4        5
# 2      12348.0       75          5   2019.40        3        4        4
# 3      12349.0       19          4   4428.69        5        3        5
# 4      12350.0      310          1    334.40        2        1        2
#
#    RFM_Score  Cluster  Segment
# 0        255        1  Regular
# 1        545        1  Regular
# 2        344        1  Regular
# 3        535        1  Regular
# 4        212        0  At-Risk

# %%
segment_df["Segment"].value_counts()
# Out:
# Segment
# Regular    3841
# At-Risk    1998
# VIP          35
# Elite         4
# Name: count, dtype: int64

# %%
churn_df["Predicted"].value_counts()
# Out:
# Predicted
# 0    589
# 1    587
# Name: count, dtype: int64

# %%
segment_df["Segment"].value_counts().plot(
    kind="bar"
)
# Out:
# <Axes: xlabel='Segment'>

# %%
churn_df["Predicted"].value_counts().plot(
    kind="bar"
)
# Out:
# <Axes: xlabel='Predicted'>

# %%
print("""
Customer Dashboard Ready
""")
# Out:
# Customer Dashboard Ready

# %%
print("""
Day 17 Completed Successfully

Tasks Completed:
- Customer Segmentation Dashboard
- Churn Risk Dashboard
- Segment Distribution Analysis
- Churn Distribution Analysis
- High Risk Customer Identification
- Dashboard Metrics

Files Used:
- customer_segments.csv
- churn_predictions.csv

Dashboard Page:
Customer Analytics
""")
# Out:
# Day 17 Completed Successfully
#
# Tasks Completed:
# - Customer Segmentation Dashboard
# - Churn Risk Dashboard
# - Segment Distribution Analysis
# - Churn Distribution Analysis
# - High Risk Customer Identification
# - Dashboard Metrics
#
# Files Used:
# - customer_segments.csv
# - churn_predictions.csv
#
# Dashboard Page:
# Customer Analytics
