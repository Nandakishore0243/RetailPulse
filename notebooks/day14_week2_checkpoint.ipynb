# %%
import pandas as pd

# %%
week2_status = pd.DataFrame({
    "Module": [
        "Prophet Forecasting",
        "LSTM Forecasting",
        "Hybrid Forecasting",
        "Churn Prediction",
        "Inventory Optimization",
        "Optuna Tuning",
        "Drift Detection",
        "Pipeline Automation"
    ],
    "Status": [
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed"
    ]
})

week2_status
# Out:
#                    Module     Status
# 0     Prophet Forecasting  Completed
# 1        LSTM Forecasting  Completed
# 2      Hybrid Forecasting  Completed
# 3        Churn Prediction  Completed
# 4  Inventory Optimization  Completed
# 5           Optuna Tuning  Completed
# 6         Drift Detection  Completed
# 7     Pipeline Automation  Completed

# %%
week2_status.to_csv(
    "../data/processed/week2_checkpoint.csv",
    index=False
)

print("Week 2 checkpoint report saved successfully!")
# Out:
# Week 2 checkpoint report saved successfully!

# %%
results = {
    "Prophet MAE": 20253.37,
    "LSTM MAE": 14078.20,
    "Hybrid MAE": 16030.93,
    "Churn Accuracy": 1.00,
    "Inventory Reorder Items": 89
}

for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Prophet MAE: 20253.37
# LSTM MAE: 14078.2
# Hybrid MAE: 16030.93
# Churn Accuracy: 1.0
# Inventory Reorder Items: 89
